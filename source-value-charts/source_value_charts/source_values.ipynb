# %%
import pandas as pd

df = pd.read_csv("source_values.csv")
df.head()
# Out:
#    annotation_id  annotator  \
# 0           4962          2
# 1           4963          2
# 2           4964          2
# 3           4965          2
# 4           4966          2
#
#                                             col_data  \
# 0  {"0":"Status | (University of Utah)","1":"comb...
# 1  {"0":"Status | (University of Utah)","1":"comb...
# 2  {"0":"Status | (University of Utah)","1":"comb...
# 3  {"0":"Status | (University of Utah)","1":"comb...
# 4  {"0":"Status | (University of Utah)","1":"comb...
#
#                     collection comments                   created_at  id  \
# 0  text-embedding-3-large_wSyn      NaN  2024-07-22T18:20:24.565094Z   1
# 1  text-embedding-3-large_wSyn      NaN  2024-07-22T18:20:28.094235Z   2
# 2  text-embedding-3-large_wSyn      NaN  2024-07-22T18:20:31.160136Z   3
# 3  text-embedding-3-large_wSyn      NaN  2024-07-22T18:20:32.889648Z   4
# 4  text-embedding-3-large_wSyn      NaN  2024-07-22T18:20:35.668061Z   5
#
# ...

# %%
from dash import Dash, html, dcc, callback, Output, Input
import plotly.express as px

app = Dash()

app.layout = [
    html.H1(children='Title of Dash App', style={'textAlign':'center'}),
]

if __name__ == '__main__':
    # Use jupyter_mode="external" and host="0.0.0.0" to make it available externally
    app.run(jupyter_mode="external",host='0.0.0.0')


# http://35.155.24.20:8050/
# Out:
# Dash app running on http://0.0.0.0:8050/
